# %%
name = "somil soni"
age = 21
print("my name is:",name)
print("my age is:",age)
# Out:
# my name is: somil soni
# my age is: 21

# %%
age2=age
print(age2)
# Out:
# 21

# %%
age=23
old=True
a=None
print(type(old))
print(type(a))
# Out:
# <class 'bool'>
# <class 'NoneType'>

# %%
a=1000
b=500
sum=a+b
print(sum)
# Out:
# 1500

# %%
a=1000
b=500
diff=a-b
print(diff)
# Out:
# 500

# %%
a,b=2,3
txt="@"
print(2*txt*3)
# Out:
# @@@@@@

# %%
a,b=2,3
c=4
print(a+b*c)
# Out:
# 14

# %%
a,b=10,5.0
c=a*b
print(c)
# Out:
# 50.0

# %%
a,b=2,4
c=a/b
print(c)
# Out:
# 0.5

# %%
a,b=1/2,4
c=a//b
print(c,a/b)
# Out:
# 0.0 0.125

# %%
a,b=-12,5
c=a//b
print(c)
# Out:
# -3

# %%
a,b=-5,2
c=a%b
print(c)
# Out:
# 1

# %%
a,b=5,-2
c=a%b
print(c)
# Out:
# -1

# %%
light=input("light color :")
if(light=="red"):
    print("stop")
elif(light=="yellow"):
    print("look")
elif(light=="green"):
    print("go")
else:
    print("light is broken")
# Out:
# light color : white
# light is broken

# %%
marks=int(input("marks :"))
if(marks>=90):
    print("a")
elif(marks>=80 and marks<90):
    print("b")
elif(marks>=70 and marks<80):
    print("c")
else:
    print("d")
# Out:
# marks : 89
# b

# %%
a=int(input("a :"))
g=input("m/f :")
if((a==1 or a==2) and g=="m"):
    print("fee is 100")
elif((a==3 or a==4) or g=="f"):
    print("fee is 200")
elif(a==5 and g=="m"):
    print("fee is 300")
else:
    print("no fee")
# Out:
# a : 5
# m/f : m
# fee is 300
