# %%
# int -> float,string,complex,boolean

i = 20
print(i,type(i)) # int

f = float(i) # int -> float
print(f,type(f)) # float

s = str(i) # int -> string 
print(s,type(s))  # string

b = bool(i)  # int -> boolean
print(b,type(b)) # boolen

c = complex(i) # int -> complex
print(c,type(c)) # complex
# Out:
# 20 <class 'int'>
# 20.0 <class 'float'>
# 20 <class 'str'>
# True <class 'bool'>
# (20+0j) <class 'complex'>

# %%
# float -> int,string,complex,boolean

f = 30.90
print(f,type(f)) # float

i = int(f) # float-> int
print(i,type(i)) # int

s = str(f) # float -> string 
print(s,type(s))  # string

b = bool(f)  # float-> boolean
print(b,type(b)) # boolen

c = complex(f) # float -> complex
print(c,type(c)) # complex
# Out:
# 30.9 <class 'float'>
# 30 <class 'int'>
# 30.9 <class 'str'>
# True <class 'bool'>
# (30.9+0j) <class 'complex'>

# %%
# string -> int,float,complex,boolean

s = "boss"
print(s,type(s)) # string

i = int(s) # string-> int
print(i,type(i)) # int

f = float(s) # string -> float 
print(f,type(f))  # float

b = bool(s)  # string -> boolean
print(b,type(b)) # boolen

c = complex(s) # string -> complex
print(c,type(c)) # complex
# Out:
# boss <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 s = "boss"
#       4 print(s,type(s)) # string
# ----> 6 i = int(s) # string-> int
#       7 print(i,type(i)) # int
#       9 f = float(s) # string -> float
#
# ValueError: invalid literal for int() with base 10: 'boss'

# %%
# string -> int,float,complex,boolean

s = "005"
print(s,type(s)) # string

i = int(s) # string-> int
print(i,type(i)) # int

f = float(s) # string -> float 
print(f,type(f))  # float

b = bool(s)  # string -> boolean
print(b,type(b)) # boolen

c = complex(s) # string -> complex
print(c,type(c)) # complex
# Out:
# 005 <class 'str'>
# 5 <class 'int'>
# 5.0 <class 'float'>
# True <class 'bool'>
# (5+0j) <class 'complex'>

# %%
# boolean -> int,float,complex,string

b = True 
print(b,type(b)) # string

i = int(b) # boolean-> int
print(i,type(i)) # int

f = float(b) # boolean -> float 
print(f,type(f))  # float

s = str(b)  # boolean-> string
print(s,type(s)) # string

c = complex(b) # boolean -> complex
print(c,type(c)) # complex
# Out:
# True <class 'bool'>
# 1 <class 'int'>
# 1.0 <class 'float'>
# True <class 'str'>
# (1+0j) <class 'complex'>
